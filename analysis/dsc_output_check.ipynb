# %%
import numpy as np
import pickle
import sys
import os
import dsc
from dsc.query_engine import Query_Processor as dscQP
from dsc import dsc_io

# %%
dsc_output = "/home/saikatbanerjee/scratch-midway2/gradvi-experiments/trial"

# %%
db = os.path.join(dsc_output, os.path.basename(os.path.normpath(dsc_output)) + ".db")
print(db)
# Out:
# /home/saikatbanerjee/scratch-midway2/gradvi-experiments/trial/trial.db

# %%
'''
Target can be any module name, group name
or module.variable
There are two groups of methods, one of them 
needs to be force removed during query (groups = ["fit_cpt:"])
'''

target = ["simulate", "fit", "mse.err", "simulate.se", "coef_mse.err"]
#condition = ["simulate.sfix == 2", "simulate.signal == 'normal'", "simulate.dims == '(50, 200)'"]
#groups = ["fit_cpt:"]
condition = [""]

# %%
qp = dscQP(db, target, condition)

# %%
qp.output_table
# Out:
#      DSC       simulate             simulate.se:output  \
# 0      1  equicorrgauss  equicorrgauss/equicorrgauss_1
# 1      1  equicorrgauss  equicorrgauss/equicorrgauss_2
# 2      1  equicorrgauss  equicorrgauss/equicorrgauss_3
# 3      1  equicorrgauss  equicorrgauss/equicorrgauss_4
# 4      2  equicorrgauss  equicorrgauss/equicorrgauss_5
# ..   ...            ...                            ...
# 267    1  equicorrgauss  equicorrgauss/equicorrgauss_4
# 268    2  equicorrgauss  equicorrgauss/equicorrgauss_5
# 269    2  equicorrgauss  equicorrgauss/equicorrgauss_6
# 270    2  equicorrgauss  equicorrgauss/equicorrgauss_7
# 271    2  equicorrgauss  equicorrgauss/equicorrgauss_8
#
#               simulate.output.file      fit  \
# 0    equicorrgauss/equicorrgauss_1    susie
# 1    equicorrgauss/equicorrgauss_2    susie
# 2    equicorrgauss/equicorrgauss_3    susie
# 3    equicorrgauss/equicorrgauss_4    susie
# 4    equicorrgauss/equicorrgauss_5    susie
# ..                             ...      ...
# 267  equicorrgauss/equicorrgauss_4  l0learn
# 268  equicorrgauss/equicorrgauss_5  l0learn
# 269  equicorrgauss/equicorrgauss_6  l0learn
# 270  equicorrgauss/equicorrgauss_7  l0learn
# 271  equicorrgauss/equicorrgauss_8  l0learn
#
#                        fit.output.file  \
# 0        susie/equicorrgauss_1_susie_1
# 1        susie/equicorrgauss_2_susie_1
# 2        susie/equicorrgauss_3_susie_1
# 3        susie/equicorrgauss_4_susie_1
# 4        susie/equicorrgauss_5_susie_1
# ..                                 ...
# 267  l0learn/equicorrgauss_4_l0learn_1
# 268  l0learn/equicorrgauss_5_l0learn_1
# 269  l0learn/equicorrgauss_6_l0learn_1
# 270  l0learn/equicorrgauss_7_l0learn_1
# 271  l0learn/equicorrgauss_8_l0learn_1
#
#                                         mse.err:output  \
# 0    mse/equicorrgauss_1_susie_1_predict_linear_1_m...
# 1    mse/equicorrgauss_2_susie_1_predict_linear_1_m...
# 2    mse/equicorrgauss_3_susie_1_predict_linear_1_m...
# 3    mse/equicorrgauss_4_susie_1_predict_linear_1_m...
# 4    mse/equicorrgauss_5_susie_1_predict_linear_1_m...
# ..                                                 ...
# 267                                                 NA
# 268                                                 NA
# 269                                                 NA
# 270                                                 NA
# 271                                                 NA
#
#                                coef_mse.err:output
# 0                                               NA
# 1                                               NA
# 2                                               NA
# 3                                               NA
# 4                                               NA
# ..                                             ...
# 267  coef_mse/equicorrgauss_4_l0learn_1_coef_mse_1
# 268  coef_mse/equicorrgauss_5_l0learn_1_coef_mse_1
# 269  coef_mse/equicorrgauss_6_l0learn_1_coef_mse_1
# 270  coef_mse/equicorrgauss_7_l0learn_1_coef_mse_1
# 271  coef_mse/equicorrgauss_8_l0learn_1_coef_mse_1
#
# [272 rows x 8 columns]
