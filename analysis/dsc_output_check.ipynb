# %%
import numpy as np
import pickle
import sys
import os
import dsc
from dsc.query_engine import Query_Processor as dscQP
from dsc import dsc_io

from pymir import pd_utils

# %%
dsc_output = "/home/saikatbanerjee/scratch/work/gradvi-experiments/linreg_indep"

# %%
db = os.path.join(dsc_output, os.path.basename(os.path.normpath(dsc_output)) + ".db")
print(db)
# Out:
# /home/saikatbanerjee/scratch/work/gradvi-experiments/linreg_indep/linreg_indep.db

# %%
'''
Target can be any module name, group name
or module.variable
There are two groups of methods, one of them 
needs to be force removed during query (groups = ["fit_cpt:"])
'''

target = ["simulate", "simulate.sfix", "fit", "mse.err", "simulate.se", "coef_mse.err"]
#condition = ["simulate.sfix == 2", "simulate.signal == 'normal'", "simulate.dims == '(50, 200)'"]
#groups = ["fit_cpt:"]
condition = [""]

# %%
qp = dscQP(db, target, condition)

# %%
qp_df = qp.output_table

# %%
qp_df
# Out:
#       DSC       simulate  simulate.sfix               simulate.se:output  \
# 0       1  equicorrgauss              1    equicorrgauss/equicorrgauss_1
# 1       1  equicorrgauss              2    equicorrgauss/equicorrgauss_2
# 2       1  equicorrgauss              5    equicorrgauss/equicorrgauss_3
# 3       1  equicorrgauss             10    equicorrgauss/equicorrgauss_4
# 4       1  equicorrgauss             20    equicorrgauss/equicorrgauss_5
# ...   ...            ...            ...                              ...
# 5095   10  equicorrgauss              1  equicorrgauss/equicorrgauss_146
# 5096   10  equicorrgauss              2  equicorrgauss/equicorrgauss_147
# 5097   10  equicorrgauss              5  equicorrgauss/equicorrgauss_148
# 5098   10  equicorrgauss             10  equicorrgauss/equicorrgauss_149
# 5099   10  equicorrgauss             20  equicorrgauss/equicorrgauss_150
#
#                  simulate.output.file      fit  \
# 0       equicorrgauss/equicorrgauss_1    susie
# 1       equicorrgauss/equicorrgauss_2    susie
# 2       equicorrgauss/equicorrgauss_3    susie
# 3       equicorrgauss/equicorrgauss_4    susie
# 4       equicorrgauss/equicorrgauss_5    susie
# ...                               ...      ...
# 5095  equicorrgauss/equicorrgauss_146  l0learn
# 5096  equicorrgauss/equicorrgauss_147  l0learn
# 5097  equicorrgauss/equicorrgauss_148  l0learn
# 5098  equicorrgauss/equicorrgauss_149  l0learn
# 5099  equicorrgauss/equicorrgauss_150  l0learn
#
#                           fit.output.file  \
# 0           susie/equicorrgauss_1_susie_1
# 1           susie/equicorrgauss_2_susie_1
# 2           susie/equicorrgauss_3_susie_1
# 3           susie/equicorrgauss_4_susie_1
# 4           susie/equicorrgauss_5_susie_1
# ...                                   ...
# 5095  l0learn/equicorrgauss_146_l0learn_1
# 5096  l0learn/equicorrgauss_147_l0learn_1
# 5097  l0learn/equicorrgauss_148_l0learn_1
# 5098  l0learn/equicorrgauss_149_l0learn_1
# 5099  l0learn/equicorrgauss_150_l0learn_1
#
#                                          mse.err:output  \
# 0     mse/equicorrgauss_1_susie_1_predict_linear_1_m...
# 1     mse/equicorrgauss_2_susie_1_predict_linear_1_m...
# 2     mse/equicorrgauss_3_susie_1_predict_linear_1_m...
# 3     mse/equicorrgauss_4_susie_1_predict_linear_1_m...
# 4     mse/equicorrgauss_5_susie_1_predict_linear_1_m...
# ...                                                 ...
# 5095                                                 NA
# 5096                                                 NA
# 5097                                                 NA
# 5098                                                 NA
# 5099                                                 NA
#
#                                   coef_mse.err:output
# 0                                                  NA
# 1                                                  NA
# 2                                                  NA
# 3                                                  NA
# 4                                                  NA
# ...                                               ...
# 5095  coef_mse/equicorrgauss_146_l0learn_1_coef_mse_1
# 5096  coef_mse/equicorrgauss_147_l0learn_1_coef_mse_1
# 5097  coef_mse/equicorrgauss_148_l0learn_1_coef_mse_1
# 5098  coef_mse/equicorrgauss_149_l0learn_1_coef_mse_1
# 5099  coef_mse/equicorrgauss_150_l0learn_1_coef_mse_1
#
# [5100 rows x 9 columns]
